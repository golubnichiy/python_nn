# %%
import matplotlib.pyplot as plt
data = plt.imread('cnn_1.png')
plt.imshow(data)
plt.show()

# %%
data.shape
# Out:
# (832, 1268, 4)

# %%
data[300:500,400:800, 0] = 0
plt.imshow(data)
plt.show()

# %%
data[:,:, 1] = 0
data[:,:, 2] = 0
plt.imshow(data)
plt.show()

# %%
data[0:100, 0:100, :]
# Out:
# array([[[0.43529412, 0.        , 0.        , 1.        ],
#         [0.44705883, 0.        , 0.        , 1.        ],
#         [0.49803922, 0.        , 0.        , 1.        ],
#         ...,
#         [0.5372549 , 0.        , 0.        , 1.        ],
#         [0.5372549 , 0.        , 0.        , 1.        ],
#         [0.5411765 , 0.        , 0.        , 1.        ]],
#
#        [[0.44313726, 0.        , 0.        , 1.        ],
#         [0.4509804 , 0.        , 0.        , 1.        ],
#         [0.5019608 , 0.        , 0.        , 1.        ],
#         ...,
#         [0.5294118 , 0.        , 0.        , 1.        ],
#         [0.53333336, 0.        , 0.        , 1.        ],
#         [0.53333336, 0.        , 0.        , 1.        ]],
#
#        [[0.4627451 , 0.        , 0.        , 1.        ],
#         [0.47058824, 0.        , 0.        , 1.        ],
#         [0.5176471 , 0.        , 0.        , 1.        ],
#         ...,
# ...
